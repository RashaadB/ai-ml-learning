# %%
import math

# print statements
print('Hello World')
print('*' * 10)

# Variables
students_count = 1000
rating = 4.00
is_published = True
course_name = 'python programming'

# Strings
message = """ 
hello 
my name is Rashaad """
# printing the amount of characters in variable message
# print(len(message))
# indexing elements in the string
print(message[2])
print(message[-3])
# # slicing strings for certain amount of charcters to return back
print(message[2:4])

# Escape Sequences
# \"
# \'
# \n (new line)
cource = "python \"programming"
print(cource)

# Formated strings
first = 'Rashaad'
last = "Bracley"
full = first + " " + last
full_name = f"{len(first)} {last}"
print(full_name)

# method strings
course = "  python programming"
print(course.upper())  # capitalize all characters#
print(course.title())  # capitalize first characters#
print(course.lower())  # lowercase all characters#
print(course.strip())  # removes white space#
print(course.find("Pro"))  # Finds the index of "Pro" 
print(course.replace('p', 'R'))  # replaces all lowercase p's to R#
print('pro' in course)  # returns True boolen if 'pro' exists#
print("pro" not in course)  # returns False boolen if 'pro' exists#

# Numbers
x = 1  # integer#
x = 1.2  # float#
x = 1 + 2j  # complex number#
print(10 - 3)
print(10 * 3)
print(10 / 3)
print(10 // 3)
print(10 % 3)
print(10 ** 3)

x = 10
x = x + 3
x += 3

# functions with numbers
print(round(1.2))
print(abs(-3.9))
print(math.ceil(1.222647))  # get the ceiling of a number#


# Type conversions
x = input('x: ')
y = int(x) + 1
print(f'x: {y}')

# Falsy boolens in python
# ""
# 0
# None
x = bool(0)

# True boolens in python
x = bool(1)
x = bool(-1)
x = bool(4)
# any sting with charaters in it is true
