# %% [markdown]
# ## Outline {.slide}
#
# - Preflight and environment checks
# - Data overview and preprocessing
# - Exploratory data analysis: key plots
# - TF-IDF and caching
# - Machine learning models: regression and classification
# - Deep learning: Keras, PyTorch, ResNet50 and YOLO
# - Embeddings, FAISS, and Gradio demo
# - Conclusions and next steps

# %% [markdown]
# ## Preflight and Environment {.slide}
#
# - The notebook performs a preflight that inspects core and optional packages and warns about known incompatible versions.
# - Flags: `SMOKE_TEST` used for shortened runs. `STRICT` can enforce strict version minimums.
#
# Speaker notes: Mention how preflight helps reproducibility and that some long steps are skipped with `SMOKE_TEST = True`. If you present live, show detected versions by running the preflight cell first.

# %% [markdown]
# ## Data Overview {.slide}
#
# - Source: `amazon_reviews_us_Apparel_v1_00.csv` with reviews and metadata.
# - Typical processing: drop NA review text and ratings, parse review dates, create features such as `review_length`, `verified_purchase_binary`, `vine_binary`.
# - Dataset used in examples: up to 50,000 rows in EDA and ML sections; embedding and FAISS demo used a reduced sample (first 1,000 rows).
#
# Speaker notes: Emphasize cleaning steps: HTML removal, non-alphanumeric filtering, lowercasing, and date parsing. Explain engineered features and why they matter for models.

# %% [markdown]
# ## EDA - Key Plots to Show {.slide}
#
# 1. Rating distribution by product category (boxplot).
# 2. Top 10 product categories by review count (bar chart).
# 3. Correlation heatmap for `helpful_votes`, `total_votes`, `verified_purchase_binary`.
# 4. Review volume over years (time series line chart).
# 5. Word cloud of most frequent words in reviews.
#
# Speaker notes: For each plot, point out the main observation. For example: which categories have higher variance in ratings, whether helpful votes correlate with review length, and trends over years indicating seasonality or data collection bias. If you ran the notebook, show the plots live.

# %% [markdown]
# ### Top 10 Product Categories by Review Count
#
# ![Top categories](./slide_images/plot_00.png)
#
# Speaker notes: Use this slide to point out which categories dominate review volume and possible data skew.

# %% [markdown]
# ### Star Rating Distribution by Product Category
#
# ![Rating distribution](./slide_images/plot_01.png)
#
# Speaker notes: Highlight variance across categories and outliers.

# %% [markdown]
# ### Correlation Heatmap
#
# ![Correlation heatmap](./slide_images/plot_02.png)
#
# Speaker notes: Call out correlations between helpful votes, total votes, and verified purchase.

# %% [markdown]
# ### Review Volume Over Years
#
# ![Reviews over time](./slide_images/plot_03.png)
#
# Speaker notes: Discuss trends and any gaps in data collection across years.

# %% [markdown]
# ## TF-IDF and Caching
#
# - The notebook builds a TF-IDF vectorizer and caches artifacts under `artifacts/tfidf.pkl` and `artifacts/tfidf_matrix.pkl`.
# - `already(path)` guard avoids recomputing expensive transforms.
#
# Speaker notes: Explain why caching speeds up iterative development and how `SMOKE_TEST` reduces `max_features` for fast demos. Suggest running the TF-IDF cell before ML slides to ensure features are available.

# %% [markdown]
# ## Machine Learning - Regression Results
#
# - Models trained: Linear Regression, Ridge, Lasso to predict `star_rating`.
# - Evaluation metrics printed: R2, MSE, RMSE for each model.
#
# Speaker notes: Show the numeric outputs from the notebook when available. If metrics are low, explain causes: limited features, using review-level aggregated features, or noisy target. Recommend adding text features (TF-IDF) or richer features for better regression performance.

# %% [markdown]
# ## Machine Learning - Classification Results
#
# - Target: sentiment class derived from TextBlob polarity mapped to `positive`, `neutral`, `negative`.
# - Models trained: Logistic Regression, Decision Tree, Random Forest, Naive Bayes, KNN, plus ensemble approaches (Random Forest, AdaBoost, Gradient Boosting, Stacking).
# - Imbalance handling: SMOTE, undersampling, and class weights were tested. Results printed as classification reports.
#
# Speaker notes: Highlight one or two models that performed best in the notebook. If class imbalance was present, explain how SMOTE changed recall/precision for minority classes. Suggest showing a confusion matrix for the chosen model.

# %% [markdown]
# ## Deep Learning - Highlights
#
# - Keras experiments: Single-layer perceptron and deeper DNNs for multi-class rating prediction. Outputs include classification reports and accuracy numbers.
# - PyTorch DNN: a small feedforward network trained and evaluated with classification report output.
# - Keras vs PyTorch timing and accuracy comparison is implemented to compare throughput and accuracy.

# %% [markdown]
# ## Computer Vision - ResNet50 Fine-tuning
#
# - The notebook includes image folder normalization, generators, and a fine-tuning workflow for ResNet50.
# - After training, the notebook prints a classification report and plots a confusion matrix for the test set.
#
# Speaker notes: Note the required dataset layout: `dataset/images/{train,val,test}/{class}/img.jpg`. If images are not present, training will stop with an error. Show confusion matrix and discuss class-level performance.

# %% [markdown]
# ### ResNet50 - Confusion Matrix (Test Set)
#
# ![ResNet confusion matrix](./slide_images/plot_09.png)
#
# Speaker notes: Use this to illustrate which classes the model confuses and possible reasons (class imbalance, small dataset).

# %% [markdown]
# ## Object Detection - YOLOv8
#
# - YOLO training is guarded: it runs only when ultralytics is available and label `.txt` files exist under `dataset`.
# - For smoke tests, training uses shorter epochs and smaller images. Full training requires setting `SMOKE_TEST = False`.
#
# Speaker notes: Explain the guard logic and where model artifacts are stored (`runs/detect/capstone_yolo_model`). If you want to show detection examples, run YOLO inference on a sample image after training or use the provided `yolov8n.pt` checkpoint for demo.

# %% [markdown]
# ## Embeddings, FAISS, and Gradio Demo
#
# - The notebook builds sentence embeddings for product titles using `sentence-transformers` and indexes them in FAISS for nearest neighbor search.
# - A fallback fuzzy matcher with `rapidfuzz` is included for string matching.
# - A RAG-style prompt builder plus a Gradio interface is implemented to generate product descriptions via the OpenAI ChatCompletion API.
#
# Speaker notes: Highlight the demo flow: user enters title, FAISS finds similar products, prompt built from retrieved titles, and an LLM generates a description. If you present, avoid showing API key on screen and verify OpenAI usage limits.

# %% [markdown]
# ## Results Summary and Recommendations
#
# - EDA: key dataset characteristics and trends in rating distributions and review volumes.
# - ML: classification pipelines and ensemble methods gave baseline performance; report specific precision and recall numbers after running the notebook in full data mode.
# - DL: ResNet50 fine-tuning shows class-level performance via confusion matrix; sequential text models provide stronger sequence-aware modeling for sentiment tasks.
# - Production notes: use caching, set `SMOKE_TEST = False` for full runs, ensure required packages and GPU availability for deep learning tasks.
#
# Speaker notes: End with clear next steps such as hyperparameter tuning, larger TF-IDF or transformer text features, or building a small web demo using the Gradio interface.

# %% [markdown]
# ## Appendix - How to turn this notebook into slides
#
# - Option A: Use Jupyter nbconvert with reveal.js to create an HTML slide deck.
# - Option B: Use `jupyter lab` with the Slides exporter or RISE extension for in-notebook presentation.
#
# Commands:
# ```bash
# # Convert to Reveal.js HTML
# jupyter nbconvert --to slides "Capstone Project/capstone_project_slides.ipynb" --reveal-prefix "https://cdnjs.cloudflare.com/ajax/libs/reveal.js/4.3.1/" --output slides.html --output-dir "Capstone Project"
# ```
#
# Speaker notes: If you want a PowerPoint, convert the HTML to PPTX using pandoc or use nbconvert to export to PDF and then convert to PPTX.
