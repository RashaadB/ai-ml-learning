# %% [markdown]
# ## LangChain for LLM application Development
#
# ## Model I/O: prompts, language models, and parsers
# # Flow of Chatbot Application
# - Large Document
# - Broken into smaller chunks
# - Chuncks stored into vector store
# - Retrieve relevant info
# - create completion with relevant info
# - get reply
#
# ## Model I/O:
# - prompts: serve as inputs for a language model and guide it on what to generate
# - Language Models: take the prompts and generate text based on their training
# - Output parsers: transform the raw output form the language model into a format that is useful and accessible.
#
# ## Document Loaders
# - first step is to import the raw document and explore the process of importing documents with examples
#
# - CSV document loader: file is a type of text file that uses comma as a delimiter to seperate values.
#
# - file directory loader: is like a filing cabinet where organized files are stored, managing data.
#
# - HTML document loader: is a standard markup language used for creating documents intended for web brower display
#
# - JSON document loader: is a standard file format and data interchange format that employs human readable text to store and transmit data objects
#
# - PDF document loader: is a file format disgned to display documents, including text formatting and images
#
# ## Text Splitters
# - splitting text and documents in Langchain, for storage and segmentation
#     - CharacterTextSplitter:
#         - in langChain divides large text into smaller sections using a defined set of separator characters to determine the chunck size
#         - The chunck size of the characterTextSplitter determines the maximum number of characters in each chunk of text
#
#     - RecursiveTextSplitter:
#         - in langChain recursively splits text into chunks for better handling, unlike characterTextSplitter, which has fixed splitting approach
#         - There are different types of text splitters avaiable in LangChain, and you can specficy parameters such as chunk size and chunk overlap
#
# ## Embeddings in GenAi
# - In genAi, embeddings conver complex data into compact vector forms. These vectors, usually floating point numbers, encapsulate the characteristics of the dataset. Vector distances indicate relatedness: smaller distances suggest a higher correctlation.
# - Embeddings represent text, images, and more in a machine friendly manner. They help Ai grasp data meaning naturally, leading to text generation, language translation, and image understanding applications.
#
# ## Text embedding Models in LangChain
# - LangChain provides a standardized interface for various embedding model providers like OpenAi, Cohere, and hugging Face
#
# - The models transform text into vector representations, enabling operations like semantic search through text similarity in vector space.
#
# - To begin text embedding models, install the required packages and set up API keys. For OpenAi in langchain, these steps are already complete
#
# - the `embed_docuements` method embeds multiple texts, providing a list of vector representations.
#
# ## VectorStore
# - VectorStore acts as storage space for embeddings. It helps quickly find and work with data representations, improving the model's performance
#
# - The vectorStore in LangChain is an abstract class that represents a store of vectors
# - It is utilized for adding vectors and documents to the store, removing items from the store, and conducting searches within the store
# - It takes care of storing embedded data and performing vector searches for you
# - There are different implementations of VectorStore based on different technologies such as ChromaDB, Faiss, pgVector databases, and pinecone
#
# ## How VectorStore Works
# - process of storing and searching over unstructured data works in the context of LangChain's VectorStore
#
#     - Embedding data:
#         - Embeddings are used to transform unstructured formats.Storing these resulant vectors is used for handling such data efficiently
#
#     - Storing Vectors:
#         - the VectorStore in LangChain takes care of storing the embedded data
#
#     - Embedding query:
#         - At the time of querying, the unstructured query is transformed into an embedded form
#
#     - Retrieving Vector:
#         - The VectorStore retrieves the embedding vectors that are similar to the embedding query
#
#     - Vector Search:
#         - VectorStore conducts a vector search, finding the most similar vectors to a given one.
#
# ## LangChain Retriever
# - LangChain retrievers are tools in LangChain that fetch information from external sources to enhance the language model's knowledge and capabilities.
# - LangChain retrievers fetch documents with unstructured queries, offering versatility beyond vectore stores, which primarily store and retrieve.
# - While vector stores can form the backbone of a retriever, there are other types of retrievers as well.
# - Retrievers take a string query as input and return a list of document objects as output.
#
# ## LangChain Chains
# - using a LLM alone is suitable for basic taks, but complex applications may require chaining LLMs or other components
# - LangChain offers two high-level frameworks for the chaining of components:
#
#     - Chain interface:
#         - this the legacy approach for chaining components.
#
#     - LangChain expression language (LCEL):
#         - This is the updated approach recommended for chain composition in new applications
#
# ## Foundational LangChain Chain
# - In applications of LLMs, chaining typically involves integrating a prompt template with the LLM and, if necessary, employing an output parser for futher refinement
#
# - An LLMChain, commonly used in LangChain, boosts language model functionality and is integrated into other chains and agents.
#
# - An LLMChain consists of a promptTemplate and a language model
#
# - The LLMChain formats the prompt template using input and memeory key values, then passes it to the LLM for output
#
# ## Sequential Chain in LangChain
# - A sequential chain in LangChain allows you to execute multiple chains in a sequence, much like a well orchestrated symphony.
#
# - The simpleSequential Chain object from the langchain.chain module enables you to create such a sequential chain.
# - To execute a simpleSequentialChain, list the desired chains and use the run() method
#
# ## Stuff Chain
# - The stuff chain in LLM generates creative content based on specific prompts, assisting in brainstorming and idea generation with language models
# - Also Known as the Stuff documents chain, its a simple way to generate documents by filling or stuffing them with content
# - It operates by taking a list of documents, incorporating them all into a prompt, and then passing that prompt to an LLM
# - This chain is particularly effective for applications where the documents are relatively small and only a few are typically passed in for most calls.
#
# ## Refine Chain
# - The refine chain in LLM imprves outputs by further processing and polishing language model generated content, enhancing its quality and coherence.
# - The refine documents chain acts like a careful craftsman, improving its output by revisiting input documents and updating answers iteratively
# - Like a craftsman focusing on one piece, the refine chain sends one document at a time to the LLM, ideal for tasks needing analysis of numerous documents.
# - Reffining tasks with lots of document referces or requiring detailed information from many documents can be tough for the refine chain
#
# ## Map Reduce Chain
# The map reduce chain in LLM simplifies complex tasks by dividing them into smaller pieces, processing each independently, and then combining the results.
# - Imagine the map reduce documents chain as a skilled artisan workinng on a complex piece or artwork.
# - First, like an artist creating each part, the map reduce chain uses an LLM chain on each document separately. This is the map step
# - next, in the reduce step, much like an artisan assembling all the individual pieces to form a single masterpiece, all the newly crafted documents are passed to a separate combined documents chain to create a single, cohesive output.
# - the Map reduce chain handles large artwork by compressing mapped doucements, ensuring they fit in the combined documents chain.
#
# ## LangChain Memory
# - Langchain Memory stores data between LLM executions. Acting as a temporary storage for information, preferences, or context in chains
# - memory plays a crucial role in conversational interffaces, allowing systems to reference past interactions.
# - This is achieved through the storage and querying of information, with two primary actions: reading and writing
# - The memory system interacts with a chain twice during a run, augmenting user inputs and storing the inputs and outputs for future reference
#
# ## Building Memory into a system
# - Storing Chat messages:
#     - Langchain memroy stores chat messages in lists and databases, ensuring recording and reference.
#
# - Querying chat messages
#     - Langchain organizes stored chat messages, allowing efficint retrieval of relevant information during conversations.
#
# ## LangChain Agents
# - Agents make use of external tools to perform specific actions. LangChain provides many out of the box agents tools.
# - LangChain agents are like the conductors of an orchestra, coordinating various components to create a harmonious output.
# - LLMs utilizie tools to access external sources like Google, wikipedia, youtube, and python REPL databases, to solve complex problems
